# %%
import cv2 
import matplotlib.pyplot as plt
import numpy as np

lena = cv2.imread('C:/Users/kaiyuchou/test_data/lena.bmp')
lena2 = lena.copy()

lena.shape #(512, 512, 3)
new_lena = np.zeros(lena.shape, int) #轉成0 

x =  lena.shape[0] #寬尺寸
y =  lena.shape[1] #長尺寸
        
for i in range(0, x, 1): #diagonally
    for j in range(0, y, 1):
        new_lena[i][j] = lena[y-1-i][x-1-j]
        
#for i in range(x): #upside_doen
    #new_lena[i, ::] = lena[x - i - 1, ::] 
    
#for i in range(0, y): #right_side_left
    #new_lena[:,i, :] = lena[:,y - i - 1, :]
    
    
#for i in range(0, x, 1): #upside_doen
    #for j in range(0, y, 1):
        #new_lena[i][j] = lena[x-1-j][j]      
    
#for i in range(0, x, 1): #right_side_left
    #for j in range(0, y, 1):
        #new_lena[i][j] = lena[i][y-1-j]    

    
#new_lena = lena[:,::-1]  #right_side_left
#new_lena = lena[::-1]  #upside_doen

plt.imshow(new_lena)
#plt.imshow(lena2)

plt.show()
